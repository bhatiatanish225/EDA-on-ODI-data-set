# %% [markdown]
# <a href="https://colab.research.google.com/github/bhatiatanish225/EDA-on-T20-data-set/blob/main/EDA_on_T20_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/ODI data.csv")
df.head()
# Out:
#    Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0           0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1           1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2           2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3           3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4           4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
#
#      HS    Ave     BF     SR 100  50   0  Unnamed: 13
# 0  200*  44.83  21367  86.23  49  96  20          NaN
# 1   169  41.98  18048  78.86  25  93  15          NaN
# 2   164  42.03  17046  80.39  30  82  20          NaN
# 3   189  32.36  14725   91.2  28  68  34          NaN
# 4   144  33.37  16020  78.96  19  77  28          NaN

# %%
df=df.drop(['Unnamed: 0'],axis=1)
df=df.drop(['Unnamed: 13'],axis=1)
df.head(5)
# Out:
#                         Player  Mat Inns  NO   Runs    HS    Ave     BF  \
# 0         SR Tendulkar (INDIA)  463  452  41  18426  200*  44.83  21367
# 1  KC Sangakkara (Asia/ICC/SL)  404  380  41  14234   169  41.98  18048
# 2         RT Ponting (AUS/ICC)  375  365  39  13704   164  42.03  17046
# 3      ST Jayasuriya (Asia/SL)  445  433  18  13430   189  32.36  14725
# 4   DPMD Jayawardene (Asia/SL)  448  418  39  12650   144  33.37  16020
#
#       SR 100  50   0
# 0  86.23  49  96  20
# 1  78.86  25  93  15
# 2  80.39  30  82  20
# 3   91.2  28  68  34
# 4  78.96  19  77  28

# %%
df.shape
# Out:
# (2500, 12)

# %%
duplicate_rows=df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Player, Mat, Inns, NO, Runs, HS, Ave, BF, SR, 100, 50, 0]
# Index: []

# %%
df.count()
# Out:
# Player    2500
# Mat       2500
# Inns      2500
# NO        2500
# Runs      2500
# HS        2500
# Ave       2500
# BF        2500
# SR        2500
# 100       2500
# 50        2500
# 0         2500
# dtype: int64

# %%
df.head()
# Out:
#                         Player  Mat Inns  NO   Runs    HS    Ave     BF  \
# 0         SR Tendulkar (INDIA)  463  452  41  18426  200*  44.83  21367
# 1  KC Sangakkara (Asia/ICC/SL)  404  380  41  14234   169  41.98  18048
# 2         RT Ponting (AUS/ICC)  375  365  39  13704   164  42.03  17046
# 3      ST Jayasuriya (Asia/SL)  445  433  18  13430   189  32.36  14725
# 4   DPMD Jayawardene (Asia/SL)  448  418  39  12650   144  33.37  16020
#
#       SR 100  50   0
# 0  86.23  49  96  20
# 1  78.86  25  93  15
# 2  80.39  30  82  20
# 3   91.2  28  68  34
# 4  78.96  19  77  28

# %%
sns.boxplot(X=df['NO'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
plt.title("Plot of runs")
sns.histplot(df['Runs'])
# Out:
# <Axes: title={'center': 'Plot of runs'}, xlabel='Runs', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['Runs'], y=df['Inns'])
# Out:
# <Axes: xlabel='Runs', ylabel='Inns'>

# %%
plt.figure(figsize=(10,5))
c= df.corr()
sns.heatmap(c)
# Out:
# <ipython-input-57-aeec2be104aa>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   c= df.corr()
# <Axes: >
